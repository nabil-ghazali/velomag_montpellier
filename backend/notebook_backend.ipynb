# %% [markdown]
# # Exploration
#
# boucler sur les données historiques de comptage de vélo avec l'ID des compteurs

# %%
import requests

BASE_URL = "https://portail-api-data.montpellier3m.fr"

# 1. Récupérer la liste des éco-compteurs
url_list = f"{BASE_URL}/ecocounter"
params_list = {
    "limit": 1000  # obligatoire dans la doc
    # "id": "urn:ngsi-ld:EcoCounter:XTH19101158"  # optionnel si tu veux filtrer sur un seul
}

r_list = requests.get(url_list, params=params_list)
print("Status code liste:", r_list.status_code)
ecocounters = r_list.json()
print(ecocounters[:2])  # pour jeter un œil aux 2 premiers


# params = {id : compteurs}

# r_bike = requests
# Out:
# Status code liste: 200
# ...
