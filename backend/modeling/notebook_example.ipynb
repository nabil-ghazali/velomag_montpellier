# %% [markdown]
# Entrainement modèle

# %%
# Load la DB, et ajoute le chemin racine du projet au path ne pas toucher !

import sys
import os
# ajoute la racine du projet
project_root = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
sys.path.append(project_root)

from backend.database.schemas import Database
import os
from dotenv import load_dotenv

load_dotenv()

USER = os.getenv("user")
PASSWORD = os.getenv("password")
HOST = os.getenv("host")
PORT = os.getenv("port")
DBNAME = os.getenv("dbname")

DATABASE_URL = f"postgresql+psycopg2://{USER}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}?sslmode=require"

db = Database(DATABASE_URL)

# %%
velo_clean = db.pull_data("velo_clean")
meteo_clean = db.pull_data("meteo_clean")
print(velo_clean.head())
print(meteo_clean.head())
# Out:
#    id            datetime                          counter_id  intensity  \
# 0   1 2024-11-30 00:00:00  urn:ngsi-ld:EcoCounter:XTH19101158       44.0
# 1   2 2024-11-30 01:00:00  urn:ngsi-ld:EcoCounter:XTH19101158       16.0
# 2   3 2024-11-30 02:00:00  urn:ngsi-ld:EcoCounter:XTH19101158        5.0
# 3   4 2024-11-30 03:00:00  urn:ngsi-ld:EcoCounter:XTH19101158        3.0
# 4   5 2024-11-30 04:00:00  urn:ngsi-ld:EcoCounter:XTH19101158        4.0
#
#         lat       lon  weekday  is_weekend  hour
# 0  43.61621  3.874408        5        True     0
# 1  43.61621  3.874408        5        True     1
# 2  43.61621  3.874408        5        True     2
# 3  43.61621  3.874408        5        True     3
# 4  43.61621  3.874408        5        True     4
#    id            datetime  temperature_2m_max  temperature_2m_min  \
# 0   1 2024-11-29 23:00:00                12.8                 3.7
# 1   2 2024-11-30 23:00:00                14.4                 6.6
# ...
